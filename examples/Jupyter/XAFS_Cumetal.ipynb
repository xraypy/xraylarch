# %%
import numpy as np
from larch.xafs import pre_edge, autobk, xftf
from larch.io import read_ascii
from larch.plot.bokeh_xafsplots import plot_mu, plot_bkg, plot_chik, plot_chir

cu = read_ascii('../xafsdata/cu_metal_rt.xdi')

cu.mu = -np.log(cu.itrans/cu.i0)

pre_edge(cu)

print(f'{cu.e0=} {cu.edge_step=:.3f}')
# Out:
# cu.e0=8980.5 cu.edge_step=2.729

# %%
# plot the mu(E) data and the pre-edge line and post-edge curve

fig = plot_mu(cu, show_e0=True, show_pre=True, show_post=True)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f3bce882-8b2f-485a-a1c2-da6cc1fd40ed">Loading BokehJS ...</span>
#     </div>
#   <div id="e75652c0-7f7d-4131-8b83-1dca21c2d132" data-root-id="p1008" style="display: contents;"></div>

# %%
# now do EXAFS background subtraction

autobk(cu, rbkg=1.0, kweight=1)

fig = plot_bkg(cu)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a1464df7-85e6-4e95-b13f-fa584b2eb6f1">Loading BokehJS ...</span>
#     </div>
#   <div id="e6fb4fb7-7d98-41b1-9b59-de8b07b794ca" data-root-id="p1086" style="display: contents;"></div>

# %%
# plot chi(k)

plot_chik(cu, kweight=2)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fd63ca5b-2197-448f-8015-2a5de230badd">Loading BokehJS ...</span>
#     </div>
#   <div id="a9c20bcc-8678-4df3-8f36-cd798ca9c818" data-root-id="p1145" style="display: contents;"></div>

# %%
# you'll sometimes see a "swoop" at high-k like this.  By default, autobk doesn't give much weight to the 
# the ends of the data ranges, but you can set a "clamp_hi" value to suppress this:

autobk(cu, rbkg=1.0, kweight=1, clamp_hi=500)
plot_chik(cu, kweight=2)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fc1b7e25-bad6-4f85-9429-7f88122fa2dc">Loading BokehJS ...</span>
#     </div>
#   <div id="b80ff2f9-9034-46ae-85ec-f1ffeddb8afa" data-root-id="p1192" style="display: contents;"></div>

# %%
# and we can calculate the Fourier transform of this data giving the k-range,
# and specifying the k-space Fourier transform window.

xftf(cu,  kweight=2, kmin=3, kmax=16, window='kaiser', dk=5)
plot_chik(cu, kweight=2, show_window=True)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b04a3559-99f1-458a-bc21-eec9f5e82019">Loading BokehJS ...</span>
#     </div>
#   <div id="e029a0c0-f8aa-480f-82f0-3b0ec9846fbc" data-root-id="p1239" style="display: contents;"></div>

# %%
# .. and plot chi(R), both the magnitude, and the real part of the complex transform

plot_chir(cu, show_mag=True, show_real=True)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ca5cba5d-b4f5-4db3-835f-b2c329b0c050">Loading BokehJS ...</span>
#     </div>
#   <div id="b496fdf5-c85f-4246-8b71-4a8cf90afef0" data-root-id="p1298" style="display: contents;"></div>
