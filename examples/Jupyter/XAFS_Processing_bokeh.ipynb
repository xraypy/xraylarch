# %%
import numpy as np
import larch
from larch.xafs import pre_edge, autobk
from larch.io import read_ascii
from larch.plot.bokeh_xafsplots import plot_mu, plot_bkg

cu = read_ascii('../xafsdata/cu_metal_rt.xdi')
cu.mu = -np.log(cu.itrans/cu.i0)
pre_edge(cu)
autobk(cu, rbkg=1, kw=2)
print(cu.e0)
# Out:
# 8980.5

# %%
fig = plot_mu(cu, with_deriv=True, show_e0=True, emin=8900, emax=9100)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e09c16ba-71ab-4169-b9bc-2a63b3b7b182">Loading BokehJS ...</span>
#     </div>
#   <div id="be923ce9-85a6-48e8-8cab-e50467a5cc8a" data-root-id="p1001" style="display: contents;"></div>

# %%
fig = plot_bkg(cu, emin=8900, emax=9600)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f4f9a6fd-8736-4e2a-9ec8-b7e61fcd1702">Loading BokehJS ...</span>
#     </div>
#   <div id="e4c2ec05-163f-4fe9-be3e-899055595785" data-root-id="p1070" style="display: contents;"></div>
