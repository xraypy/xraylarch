# %%
import numpy as np
import larch
from larch.xafs import pre_edge, autobk
from larch.io import read_ascii
from larch.plot.bokeh_xafsplots import plot_mu, plot_bkg, plot_chik

cu = read_ascii('../xafsdata/cu_metal_rt.xdi')
cu.mu = -np.log(cu.itrans/cu.i0)
pre_edge(cu)
autobk(cu, rbkg=1, kw=2)
print(f'{cu.e0=}')
# Out:
# cu.e0=8980.5

# %%
fig = plot_mu(cu, with_deriv=False, show_e0=True)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f2e8801d-4615-4c77-b30f-559d3cd285e1">Loading BokehJS ...</span>
#     </div>
#   <div id="d9cee089-71e2-433a-98c2-bdf198965b03" data-root-id="p1062" style="display: contents;"></div>

# %%
fig = plot_bkg(cu)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b7abeedb-5519-454f-b66f-bfee5c14c97a">Loading BokehJS ...</span>
#     </div>
#   <div id="d1a39a7a-af32-46f8-b433-f942e2d12ba2" data-root-id="p1116" style="display: contents;"></div>

# %%
plot_chik(cu, kweight=2)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e405c9ea-4131-4474-ba4c-4977c729ea3b">Loading BokehJS ...</span>
#     </div>
#   <div id="f37cd98b-935e-49aa-9583-4bf0ebda746a" data-root-id="p1175" style="display: contents;"></div>
