# %%
import numpy as np
import larch
from larch.xafs import pre_edge, autobk
from larch.io import read_ascii
from larch.plot.bokeh_xafsplots import plot_mu, plot_bkg

cu = read_ascii('../xafsdata/cu_metal_rt.xdi')
cu.mu = -np.log(cu.itrans/cu.i0)
pre_edge(cu)
autobk(cu, rbkg=1, kw=2)
print(cu.e0)
# Out:
# 8980.5

# %%
fig = plot_mu(cu, with_deriv=True, show_e0=True, emin=8900, emax=9100)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b12953fd-0867-405d-9f81-e82fdc464438">Loading BokehJS ...</span>
#     </div>
#   <div id="cfdaa7cb-be07-49cd-bc20-1bdcae33eff3" data-root-id="p1209" style="display: contents;"></div>

# %%
fig = plot_bkg(cu, emin=8900, emax=9600)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e9b9846e-295c-4a89-92af-7f72869342a4">Loading BokehJS ...</span>
#     </div>
#   <div id="f2074902-612f-4e82-9650-a425cbaee700" data-root-id="p1280" style="display: contents;"></div>
